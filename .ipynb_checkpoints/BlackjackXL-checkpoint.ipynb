# %%
from BlackjackXL import main

# %%
main()
# Out:
# BIENVENID@ AL CASINO DE XABI... A ver si consigues no perderlo todo ;)
#
# >>>>> Introduce tu nombre: Xabi
#
# >>>>> Introduce tu saldo (€): diez
#
# 	Introduce un número positivo
#
# >>>>> Introduce tu saldo (€): 10
#
# Bienvenid@ Xabi, no olvides jugar con responsabilidad (y no perderlo todo)
# ________________________________________________________________________________________
#
# Arranca la 1ra RONDA
#
# >>>>> Apuesta ronda 1 (menos de 10.0€): 5
#
# Reparto inicial de cartas...
#
# Carta visible banca ('♠', 'A')
#
# Cartas Xabi: [('♥', 8), ('♦', 10)]
#
# Valor Xabi: 18
#
#
# ------------------------------
#
# >>>>> Elige carta (C) o  plantarte (P): p
#
# Carta oculta banca ('♣', 8)
#
# Cartas banca: [('♠', 'A'), ('♣', 8)]
#
# Valor banca: 19
#
#
# ------------------------------
#
# Gana la banca por tener un valor de cartas más alto!
#
# ... tu saldo restante es de 5.0€
#
# >>>>> Continuar? SI o  NO: si
# ...
